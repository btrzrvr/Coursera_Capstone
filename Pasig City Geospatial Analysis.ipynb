# %% [markdown]
# ## Introduction/Business Problem
#
# In this time of crisis where many places in the world are under community quarantine, a lot of businesses are closed except for some like restaurants and grocery stores. Thus, the volume of consumers in these shops have grown and since social distancing is practised, it would take several hours just to buy food and other basic necessities because the number of people that can shop inside the supermarket is limited.
#
# In the past few days, our local government has come up with a solution called _Mobile Palengkes_ (Mobile Market) which is a group of trucks with goods from the market roaming around each _barangay_ in the city so that the people wouldn't need to go to the crowded market, therefore lessening contact with other persons.
#
# However, since the truck units are limited, not every neighborhood in the city has the chance to shop in one of these.
#
# In this analysis, the goal is to identify which parts of the city is are the best spots for these _Mobile Palengkes_ in terms of barangay population and existing supermarkets ratio.

# %% [markdown]
# ## Data

# %%
import pandas as pd

# %% [markdown]
# The data below shows the district number, Population, Area, and Density of all the barangays in Pasig City.

# %%
pasig_df = pd.read_html('https://en.wikipedia.org/wiki/Pasig')[5]
pasig_df = pasig_df[:-1] # removes the last row
pasig_df['Barangays'][5] = 'Dela Paz' # fix spelling
pasig_df['Barangays'][10] = 'Manggahan'
pasig_df = pasig_df[pasig_df['District'] == "1st"] # get 1st district Barangays only
pasig_df
# Out:
#            Barangays District Population Area (ha) Density (/km2)
# 0        Bagong Ilog      1st      15454    124.95            124
# 1   Bagong Katipunan      1st       1185      4.78            248
# 2            Bambang      1st      19258     38.41            501
# 3             Buting      1st       9073     20.33            446
# 4           Caniogan      1st      21769    167.94            130
# 6           Kalawaan      1st      23442    209.91            112
# 7          Kapasigan      1st       6569     21.15            311
# 8          Kapitolyo      1st      20451     95.24            215
# 9            Malinao      1st       5957     28.02            213
# 12            Oranbo      1st       4395     43.61            101
# 13           Palatiw      1st      16929     24.24            698
# 15            Pineda      1st      15013     79.85            188
# 17             Sagad      1st       6887     12.00            574
# 18       San Antonio      1st      11666     82.07            142
# 19       San Joaquin      1st      12498     45.07            277
# 20          San Jose      1st       2347      9.33            252
# 22       San Nicolas      1st       1542     30.38             51
# 23        Santa Cruz      1st       4367      7.28            600
# 25        Santa Rosa      1st       1515     12.06            126
# 26       Santo Tomas      1st       6375     10.43            611
# 28          Sumilang      1st       5392     17.18            314
# 29             Ugong      1st      22266    375.38             59

# %% [markdown]
# ### Read barangay geospatial coordinates

# %%
coords = pd.read_csv('Pasig City Barangay Coordinates.csv', names=['Barangays', 'Latitude', 'Longitude'])
coords
# Out:
#            Barangays  Latitude  Longitude
# 0          Barangays  Latitude  Longitude
# 1        Bagong Ilog   14.5673   121.0681
# 2   Bagong Katipunan   14.5591   121.0747
# 3            Bambang   14.5554   121.0801
# 4             Buting   14.5547   121.0672
# 5           Caniogan   14.5719   121.0779
# 6           Dela Paz   14.6154   121.0994
# 7           Kalawaan   14.5488   121.0866
# 8          Kapasigan   14.5638   121.0758
# 9          Kapitolyo   14.5692   121.0602
# 10           Malinao   14.5595   121.0787
# 11         Manggahan   14.6019   121.0937
# 12          Maybunga   14.5763    121.085
# 13            Oranbo   14.5758   121.0643
# 14           Palatiw   14.5636   121.0858
# 15      Pinagbuhatan   14.5497   121.0977
# 16            Pineda   14.5636   121.0636
# 17           Rosario   14.5885   121.0891
# 18             Sagad   14.5656    121.079
# 19       San Antonio   14.5831   121.0592
# 20       San Joaquin   14.5522   121.0758
# 21          San Jose   14.5605    121.074
# 22        San Miguel   14.5672   121.0923
# 23       San Nicolas   14.5609   121.0804
# 24        Santa Cruz   14.5629   121.0797
# 25       Santa Lucia    14.584   121.1012
# 26        Santa Rosa   14.5577   121.0711
# 27       Santo Tomas   14.5615    121.083
# 28          Santolan   14.6131    121.088
# 29          Sumilang   14.5563   121.0744
# 30             Ugong   14.5844   121.0715

# %% [markdown]
# ### Adding the coordinates to the initial dataframe

# %%
final_df = pd.merge(pasig_df, coords, on='Barangays')
final_df
# Out:
#            Barangays District Population Area (ha) Density (/km2) Latitude  \
# 0        Bagong Ilog      1st      15454    124.95            124  14.5673
# 1   Bagong Katipunan      1st       1185      4.78            248  14.5591
# 2            Bambang      1st      19258     38.41            501  14.5554
# 3             Buting      1st       9073     20.33            446  14.5547
# 4           Caniogan      1st      21769    167.94            130  14.5719
# 5           Kalawaan      1st      23442    209.91            112  14.5488
# 6          Kapasigan      1st       6569     21.15            311  14.5638
# 7          Kapitolyo      1st      20451     95.24            215  14.5692
# 8            Malinao      1st       5957     28.02            213  14.5595
# 9             Oranbo      1st       4395     43.61            101  14.5758
# 10           Palatiw      1st      16929     24.24            698  14.5636
# 11            Pineda      1st      15013     79.85            188  14.5636
# 12             Sagad      1st       6887     12.00            574  14.5656
# 13       San Antonio      1st      11666     82.07            142  14.5831
# 14       San Joaquin      1st      12498     45.07            277  14.5522
# 15          San Jose      1st       2347      9.33            252  14.5605
# 16       San Nicolas      1st       1542     30.38             51  14.5609
# 17        Santa Cruz      1st       4367      7.28            600  14.5629
# 18        Santa Rosa      1st       1515     12.06            126  14.5577
# 19       Santo Tomas      1st       6375     10.43            611  14.5615
# 20          Sumilang      1st       5392     17.18            314  14.5563
# 21             Ugong      1st      22266    375.38             59  14.5844
#
#    Longitude
# 0   121.0681
# 1   121.0747
# 2   121.0801
# 3   121.0672
# 4   121.0779
# 5   121.0866
# 6   121.0758
# 7   121.0602
# 8   121.0787
# 9   121.0643
# 10  121.0858
# 11  121.0636
# 12   121.079
# 13  121.0592
# 14  121.0758
# 15   121.074
# 16  121.0804
# 17  121.0797
# 18  121.0711
# 19   121.083
# 20  121.0744
# 21  121.0715

# %%
import folium

# %%
pasig_map = folium.Map(location=[14.5764, 121.0851], zoom_start=13)
pasig_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for lat, lng, barangay in zip(final_df['Latitude'], final_df['Longitude'], final_df['Barangays']):
    label = '{}'.format(barangay)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(pasig_map)  
    
pasig_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Setup Foursquare Credentials

# %%
CLIENT_ID = 'DGNQU5N1GZ1HZQ1UJQRSUDUYX2ZOHVRZHIJI2T5V3IHKVACG'
CLIENT_SECRET = 'M3YKN5GUP314DKXSIYCFK5ONAPYMYHUGAMSNKH4EVQIQSGMM'
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DGNQU5N1GZ1HZQ1UJQRSUDUYX2ZOHVRZHIJI2T5V3IHKVACG
# CLIENT_SECRET:M3YKN5GUP314DKXSIYCFK5ONAPYMYHUGAMSNKH4EVQIQSGMM

# %% [markdown]
# ### Exploring the first Barangay

# %%
final_df.loc[0, 'Barangays']
# Out:
# 'Bagong Ilog'

# %% [markdown]
# Getting the Barangays latitude and longitude:

# %%
brgy_latitude = final_df.loc[0, 'Latitude'] 
brgy_longitude = final_df.loc[0, 'Longitude'] 

brgy_name = final_df.loc[0, 'Barangays']

print('Latitude and longitude values of {} are {}, {}.'.format(brgy_name, 
                                                               brgy_latitude, 
                                                               brgy_longitude))
# Out:
# Latitude and longitude values of Bagong Ilog are 14.5673, 121.0681.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    brgy_latitude, 
    brgy_longitude,
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=DGNQU5N1GZ1HZQ1UJQRSUDUYX2ZOHVRZHIJI2T5V3IHKVACG&client_secret=M3YKN5GUP314DKXSIYCFK5ONAPYMYHUGAMSNKH4EVQIQSGMM&v=20180605&ll=14.5673,121.0681&radius=500&limit=100'

# %%
import requests 

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9ee5e869babe001b2eca29'},
#  'response': {'venues': [{'id': '4b9b6218f964a520f50336e3',
#     'name': 'Kawilihan Village',
#     'location': {'address': 'Pasig',
#      'lat': 14.56710257497792,
#      'lng': 121.06727900114576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56710257497792,
#        'lng': 121.06727900114576}],
#      'distance': 91,
#      'postalCode': '1600',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig', '1600 Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4f2a210c4b9023bd5841ed28',
#       'name': 'Housing Development',
#       'pluralName': 'Housing Developments',
#       'shortName': 'Housing Development',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/housingdevelopment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4d4533f9bf61a1cd1d2011ac',
#     'name': 'Kawilihan Village Park',
#     'location': {'address': 'Kawilihan Village',
#      'lat': 14.56770433367514,
#      'lng': 121.06752187321982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56770433367514,
#        'lng': 121.06752187321982}],
#      'distance': 76,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Kawilihan Village',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4bbddba44e069c7486329fe3',
#     'name': 'Shell Bagong Ilog',
#     'location': {'address': 'Shaw Blvd',
#      'lat': 14.567646136857846,
#      'lng': 121.06751240804138,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567646136857846,
#        'lng': 121.06751240804138}],
#      'distance': 74,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Shaw Blvd', 'Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4c5f92c113791b8d95dd4daf',
#     'name': 'KTown Laundry Shop',
#     'location': {'address': 'Kawilihan Lane',
#      'lat': 14.567815,
#      'lng': 121.067569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567815,
#        'lng': 121.067569}],
#      'distance': 80,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Kawilihan Lane',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1fc941735',
#       'name': 'Laundry Service',
#       'pluralName': 'Laundry Services',
#       'shortName': 'Laundry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/laundry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4d84359c50913704ef007b5b',
#     'name': 'Edsa Shangri-La Parking',
#     'location': {'address': 'Edsa Shangri-La',
#      'lat': 14.581506811867342,
#      'lng': 121.05733036994933,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.581506811867342,
#        'lng': 121.05733036994933}],
#      'distance': 1961,
#      'cc': 'PH',
#      'city': 'Mandaluyong City',
#      'state': 'Lungsod ng Mandaluyong',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Edsa Shangri-La',
#       'Mandaluyong City',
#       'Lungsod ng Mandaluyong',
#       'Pilipinas']},
#     'categories': [{'id': '4c38df4de52ce0d596b336e1',
#       'name': 'Parking',
#       'pluralName': 'Parking',
#       'shortName': 'Parking',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4f112811e4b0044a22ed4980',
#     'name': "Victoria's Court",
#     'location': {'address': 'Manila',
#      'lat': 14.5676738476494,
#      'lng': 121.06753479879457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.5676738476494,
#        'lng': 121.06753479879457}],
#      'distance': 73,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Manila', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5312d16011d275b62b87cadf',
#     'name': "Borjeous' Game room",
#     'location': {'lat': 14.567212,
#      'lng': 121.068155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567212,
#        'lng': 121.068155}],
#      'distance': 11,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1e1931735',
#       'name': 'Arcade',
#       'pluralName': 'Arcades',
#       'shortName': 'Arcade',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5141efdae4b0041cb5a14615',
#     'name': "king arthur's palace",
#     'location': {'lat': 14.56772143071856,
#      'lng': 121.06761876408187,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56772143071856,
#        'lng': 121.06761876408187}],
#      'distance': 69,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4cb7b234bac9370417e5d67c',
#     'name': 'RB&A Building',
#     'location': {'address': '166 Lakeview drive',
#      'crossStreet': 'Kawilihan Lane',
#      'lat': 14.567465933906655,
#      'lng': 121.06626919531399,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567465933906655,
#        'lng': 121.06626919531399}],
#      'distance': 198,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['166 Lakeview drive (Kawilihan Lane)',
#       'Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '51f0aae2498e9f9edd8518ac',
#     'name': 'Lumiere Residences | DMCI Homes',
#     'location': {'lat': 14.569730375779521,
#      'lng': 121.06650025868417,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.569730375779521,
#        'lng': 121.06650025868417}],
#      'distance': 320,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4e00c2841f6ef39c2940f75b',
#     'name': "bennok's gym",
#     'location': {'lat': 14.567716636309544,
#      'lng': 121.06752114006952,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567716636309544,
#        'lng': 121.06752114006952}],
#      'distance': 77,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4c1cd6fb8b3aa5935a74995f',
#     'name': 'Burger Boys',
#     'location': {'address': 'Seaoil, Pasig Boulevard',
#      'lat': 14.567717461284515,
#      'lng': 121.06752395882484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567717461284515,
#        'lng': 121.06752395882484}],
#      'distance': 77,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Seaoil, Pasig Boulevard',
#       'Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '56b70648498ef040e51b17d8',
#     'name': 'Fariñas Ilocos Empanada',
#     'location': {'address': 'Pasig Blvd',
#      'lat': 14.567943851340925,
#      'lng': 121.06621989540254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567943851340925,
#        'lng': 121.06621989540254}],
#      'distance': 214,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig Blvd', 'Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a00',
#       'name': 'Comfort Food Restaurant',
#       'pluralName': 'Comfort Food Restaurants',
#       'shortName': 'Comfort Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5049f2a5e4b0da9fc10b3f9e',
#     'name': 'Ferrari Room',
#     'location': {'address': 'Shaw Blvd',
#      'lat': 14.56685,
#      'lng': 121.0658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56685,
#        'lng': 121.0658}],
#      'distance': 252,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Shaw Blvd', 'Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4ff78ebce4b0211bc2d59a65',
#     'name': "Hen's Nook",
#     'location': {'lat': 14.56762394865762,
#      'lng': 121.06655716896057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56762394865762,
#        'lng': 121.06655716896057}],
#      'distance': 170,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5155ab17e4b08bfe2353273f',
#     'name': 'McCafé The Fort',
#     'location': {'lat': 14.566343028107502,
#      'lng': 121.06947718075662,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566343028107502,
#        'lng': 121.06947718075662}],
#      'distance': 182,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5b94f291b6b04b002ce5b225',
#     'name': 'Our Lady Of La Virgen De Fatima Chapel',
#     'location': {'crossStreet': 'Kagandahan Street',
#      'lat': 14.565847,
#      'lng': 121.067781,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.565847,
#        'lng': 121.067781}],
#      'distance': 165,
#      'postalCode': '1600',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Kagandahan Street',
#       '1600 Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4bf09672f45ec928fc0a943c',
#     'name': 'SeaOil Shaw-Pasig Blvd.',
#     'location': {'lat': 14.567757425197481,
#      'lng': 121.06753749767594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567757425197481,
#        'lng': 121.06753749767594}],
#      'distance': 79,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4bfa8408633d9c7427140843',
#     'name': 'Seaoil',
#     'location': {'address': 'Pasig Blvd',
#      'crossStreet': 'at main st',
#      'lat': 14.567842010860614,
#      'lng': 121.06643915176392,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567842010860614,
#        'lng': 121.06643915176392}],
#      'distance': 188,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig Blvd (at main st)',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4ca9b34af47ea1434e458121',
#     'name': 'Our Lady Of Fatima (Kawilihan Chapel)',
#     'location': {'address': 'Kawilihan Village',
#      'lat': 14.566724944174338,
#      'lng': 121.06777147578255,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566724944174338,
#        'lng': 121.06777147578255}],
#      'distance': 73,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Kawilihan Village',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d132941735',
#       'name': 'Church',
#       'pluralName': 'Churches',
#       'shortName': 'Church',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '555bcc74498e7cf65c58c24c',
#     'name': 'Universal Robina Corporation',
#     'location': {'address': 'E. Rodriguez Jr. Avenue, Bagong Ilog',
#      'lat': 14.56798616906524,
#      'lng': 121.0696683600432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56798616906524,
#        'lng': 121.0696683600432}],
#      'distance': 185,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['E. Rodriguez Jr. Avenue, Bagong Ilog',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5b191f93012358002cf079ab',
#     'name': 'Ministop',
#     'location': {'address': 'Westlake Bldg.',
#      'crossStreet': 'Pasig Blvd.',
#      'lat': 14.567459,
#      'lng': 121.066284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567459,
#        'lng': 121.066284}],
#      'distance': 196,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Westlake Bldg. (Pasig Blvd.)',
#       'Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '570bf218498e19cf0765a388',
#     'name': 'White Palace Spa',
#     'location': {'address': 'Pasig White Lake',
#      'lat': 14.56763329678448,
#      'lng': 121.06608498891718,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56763329678448,
#        'lng': 121.06608498891718}],
#      'distance': 220,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig White Lake', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5af191e2b3c961002c36314a',
#     'name': 'Westlake Building',
#     'location': {'crossStreet': 'Shaw Blvd.',
#      'lat': 14.567676,
#      'lng': 121.066216,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567676,
#        'lng': 121.066216}],
#      'distance': 207,
#      'postalCode': '1605',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Shaw Blvd.', '1605 Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '53391938498e46f6dba881e2',
#     'name': 'Bibby Ship Management',
#     'location': {'address': 'Pasig Blvd.',
#      'lat': 14.567312,
#      'lng': 121.066021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567312,
#        'lng': 121.066021}],
#      'distance': 223,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig Blvd.', 'Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4bc48a01f8219c74a377b710',
#     'name': 'Fil-Oil, Pasig',
#     'location': {'address': 'Shaw Boulevard',
#      'lat': 14.566571,
#      'lng': 121.065812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566571,
#        'lng': 121.065812}],
#      'distance': 259,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Shaw Boulevard',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4bc8762192b376b06767513a',
#     'name': 'Coco Cabana',
#     'location': {'address': 'Kalayaan',
#      'lat': 14.5678166,
#      'lng': 121.068418,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.5678166,
#        'lng': 121.068418}],
#      'distance': 66,
#      'cc': 'PH',
#      'city': 'Makati City',
#      'state': 'Makati City',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Kalayaan',
#       'Makati City',
#       'Makati City',
#       'Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '560cf640498ee0b1f9bdb90e',
#     'name': "Ate Lyn's Ihawan",
#     'location': {'lat': 14.568008,
#      'lng': 121.069638,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568008,
#        'lng': 121.069638}],
#      'distance': 183,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4e0dd7b618a8bf9784c66b00',
#     'name': 'Lakeview Drive IXM',
#     'location': {'lat': 14.567280386748422,
#      'lng': 121.066426451505,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567280386748422,
#        'lng': 121.066426451505}],
#      'distance': 180,
#      'cc': 'PH',
#      'city': 'Quezon City',
#      'state': 'Quezon City',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Quezon City', 'Quezon City', 'Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '55c02250498e0c7be6eb8d40',
#     'name': 'URC - Cafeteria',
#     'location': {'lat': 14.567931889405807,
#      'lng': 121.0695387543112,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567931889405807,
#        'lng': 121.0695387543112}],
#      'distance': 170,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4bede6c1e24d20a134347214',
#     'name': 'Petron Shaw-Pasig Blvd.',
#     'location': {'lat': 14.567127905020564,
#      'lng': 121.06587287768517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567127905020564,
#        'lng': 121.06587287768517}],
#      'distance': 240,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4cb78ad0c7228cfaacb800ce',
#     'name': 'Powercap Trading and Construction Supply',
#     'location': {'address': 'San Roque Street',
#      'lat': 14.56698,
#      'lng': 121.066033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56698,
#        'lng': 121.066033}],
#      'distance': 225,
#      'postalCode': '1603',
#      'cc': 'PH',
#      'city': 'Pasay City',
#      'state': 'Pasay City',
#      'country': 'Pilipinas',
#      'formattedAddress': ['San Roque Street',
#       '1603 Pasig City',
#       'Pasay City',
#       'Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4fc76999e4b01153fc94dbc0',
#     'name': 'Lakeview Streetball Club',
#     'location': {'lat': 14.568364,
#      'lng': 121.066784,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568364,
#        'lng': 121.066784}],
#      'distance': 184,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1e1941735',
#       'name': 'Basketball Court',
#       'pluralName': 'Basketball Courts',
#       'shortName': 'Basketball Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '521b279011d26cfb0ca84185',
#     'name': 'Kawilihan Basketball Court',
#     'location': {'lat': 14.565673459225357,
#      'lng': 121.06798261298236,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.565673459225357,
#        'lng': 121.06798261298236}],
#      'distance': 181,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1e1941735',
#       'name': 'Basketball Court',
#       'pluralName': 'Basketball Courts',
#       'shortName': 'Basketball Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5d1948332f2fcc0023367672',
#     'name': 'Lumiere Gym',
#     'location': {'address': 'Lumiere Residences',
#      'lat': 14.569096,
#      'lng': 121.06758,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.569096,
#        'lng': 121.06758}],
#      'distance': 207,
#      'postalCode': '1605',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Lumiere Residences',
#       '1605 Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4cc346c138aaa09387e90b62',
#     'name': 'Rosal Hotel',
#     'location': {'crossStreet': 'Service rd',
#      'lat': 14.566676494502591,
#      'lng': 121.0694268023703,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566676494502591,
#        'lng': 121.0694268023703}],
#      'distance': 158,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '504316e3e4b043734b7404a0',
#     'name': 'Amber Restaurant Kapitolyo',
#     'location': {'lat': 14.566472773395976,
#      'lng': 121.06991379255325,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566472773395976,
#        'lng': 121.06991379255325}],
#      'distance': 216,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5639d26ccd10493f51aaad58',
#     'name': 'URC - Procurement Office',
#     'location': {'address': 'E. Rodriguez Junior Avenue, Bagong Ilog, Pasig City',
#      'lat': 14.567941,
#      'lng': 121.069866,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567941,
#        'lng': 121.069866}],
#      'distance': 203,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['E. Rodriguez Junior Avenue, Bagong Ilog, Pasig City',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4ea9cf712c5b5d71e6887046',
#     'name': "Dr. Casino's Clinic @ pineda pasig city",
#     'location': {'lat': 14.567752998960572,
#      'lng': 121.06750681035243,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567752998960572,
#        'lng': 121.06750681035243}],
#      'distance': 81,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4d7b562f049edcb34823c5c0',
#     'name': 'Animal Clinic',
#     'location': {'address': 'Pasig Blvd',
#      'crossStreet': 'pasig blvd near rose marie lane',
#      'lat': 14.56854462365575,
#      'lng': 121.0662331130189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56854462365575,
#        'lng': 121.0662331130189}],
#      'distance': 244,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig Blvd (pasig blvd near rose marie lane)',
#       'Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4d954af4a243a5684765b473',
#       'name': 'Veterinarian',
#       'pluralName': 'Veterinarians',
#       'shortName': 'Veterinarians',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_veterinarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5353a1d711d256c67cd12b4e',
#     'name': 'Master Barber Shop And Salon',
#     'location': {'lat': 14.5671754,
#      'lng': 121.0658776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.5671754,
#        'lng': 121.0658776}],
#      'distance': 239,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5131bc43e4b0ca4ec43e4c2a',
#     'name': "Borjeous' Mini Gym",
#     'location': {'lat': 14.567121,
#      'lng': 121.068152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567121,
#        'lng': 121.068152}],
#      'distance': 20,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '54f2cd0d498e8baffb314dab',
#     'name': 'Eight Ounce Coffee + Kitchen',
#     'location': {'address': '1227 Pasig Blvd',
#      'lat': 14.566819,
#      'lng': 121.065768,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566819,
#        'lng': 121.065768}],
#      'distance': 256,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['1227 Pasig Blvd',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4ba0ac38f964a520e97637e3',
#     'name': 'URC Main Office',
#     'location': {'address': 'E. Rodriguez Jr Ave',
#      'lat': 14.568332603924809,
#      'lng': 121.07023845157879,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568332603924809,
#        'lng': 121.07023845157879}],
#      'distance': 257,
#      'postalCode': '1600',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['E. Rodriguez Jr Ave',
#       '1600 Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4fc81e38e4b0896b9f25c4cd',
#     'name': 'Petron',
#     'location': {'address': 'Pasig Blvd. (Capitol 8)',
#      'crossStreet': 'at San Ignacio St.',
#      'lat': 14.567090930217732,
#      'lng': 121.06574473919515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567090930217732,
#        'lng': 121.06574473919515}],
#      'distance': 254,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig Blvd. (Capitol 8) (at San Ignacio St.)',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '538f24c9498e9c843c3af92b',
#     'name': 'Jv angeles construction corporation',
#     'location': {'address': '#1 E. Rodriguez Jr. Ave Bagong',
#      'lat': 14.566022,
#      'lng': 121.069891,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566022,
#        'lng': 121.069891}],
#      'distance': 239,
#      'postalCode': '1600',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['#1 E. Rodriguez Jr. Ave Bagong',
#       '1600 Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '52aea13511d243067d9e423d',
#     'name': 'Government Service Insurance System (GSIS)',
#     'location': {'address': 'Pasig Blvd cor Rosemary Lane',
#      'lat': 14.567690605040669,
#      'lng': 121.06606788026075,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567690605040669,
#        'lng': 121.06606788026075}],
#      'distance': 223,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig Blvd cor Rosemary Lane',
#       'Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1f1',
#       'name': 'Insurance Office',
#       'pluralName': 'Insurance Offices',
#       'shortName': 'Insurance Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4c568b9530d82d7f5ec8d762',
#     'name': 'Wishcraft',
#     'location': {'address': '160 Pasig boulevard',
#      'lat': 14.56823917633281,
#      'lng': 121.06813934755391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56823917633281,
#        'lng': 121.06813934755391}],
#      'distance': 104,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['160 Pasig boulevard',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5ad6e0f695a7225baa3eb093',
#     'name': 'Major Homes - Pasig',
#     'location': {'lat': 14.567524,
#      'lng': 121.066014,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567524,
#        'lng': 121.066014}],
#      'distance': 226,
#      'postalCode': '1603',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['1603 Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '50e96419e4b06559d7dd0785',
#     'name': 'One Olive Bistro',
#     'location': {'address': 'Unit 3 Elements at Rosemary Bldg. Pasig Blvd.',
#      'lat': 14.568145157412914,
#      'lng': 121.06622541429364,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568145157412914,
#        'lng': 121.06622541429364}],
#      'distance': 222,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Unit 3 Elements at Rosemary Bldg. Pasig Blvd.',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '45592388'},
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5298a32c498ec023cdb51158',
#     'name': 'Bar K',
#     'location': {'address': 'Kawilihan Village',
#      'lat': 14.568711113410647,
#      'lng': 121.06806657795684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568711113410647,
#        'lng': 121.06806657795684}],
#      'distance': 157,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Kawilihan Village',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'shortName': 'Beer Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5357c546498ecf64f98d0907',
#     'name': 'Chic-boy Chicken And Baboy',
#     'location': {'lat': 14.5671754,
#      'lng': 121.0658776,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.5671754,
#        'lng': 121.0658776}],
#      'distance': 239,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '51585772e4b0a9d4ce66a07b',
#     'name': 'room over under',
#     'location': {'lat': 14.567342758178711,
#      'lng': 121.06688690185547,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567342758178711,
#        'lng': 121.06688690185547}],
#      'distance': 130,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4e369e5fc65b2313e2993c94',
#     'name': 'Sanctuary',
#     'location': {'lat': 14.567231,
#      'lng': 121.067188,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567231,
#        'lng': 121.067188}],
#      'distance': 98,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4cfc78d9dccef04d52abc09c',
#     'name': 'Wishcraft Creative Affairs Team',
#     'location': {'address': '160 Pasig Blvd',
#      'lat': 14.56693789654147,
#      'lng': 121.06600458062721,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56693789654147,
#        'lng': 121.06600458062721}],
#      'distance': 229,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['160 Pasig Blvd',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '507a92d0e4b0bf54e21cbea5',
#     'name': 'Dormitoryana Katipunan',
#     'location': {'lat': 14.566706145424623,
#      'lng': 121.06775870609702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566706145424623,
#        'lng': 121.06775870609702}],
#      'distance': 75,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4f9ce717e4b05e5ed8327da3',
#     'name': 'Gruppo Barbero - Pasig',
#     'location': {'lat': 14.568049706270228,
#      'lng': 121.0662193349691,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568049706270228,
#        'lng': 121.0662193349691}],
#      'distance': 219,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '549a45a9498e74b7b157cb82',
#     'name': 'Pasig City Dog Pound',
#     'location': {'lat': 14.567335492932472,
#      'lng': 121.06611857544424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567335492932472,
#        'lng': 121.06611857544424}],
#      'distance': 213,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '50328a8e91d4c4b30a586d6c',
#       'name': 'Non-Profit',
#       'pluralName': 'Non-Profits',
#       'shortName': 'Non-Profit',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4e7953e38998654c74ae7aec',
#     'name': 'Pldt Bagong Ilog',
#     'location': {'lat': 14.567654594068589,
#      'lng': 121.06752360341851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567654594068589,
#        'lng': 121.06752360341851}],
#      'distance': 73,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '503c004de4b06ee16f7ffa75',
#     'name': 'Gulf Petroleum',
#     'location': {'address': 'Pinagbuhatan',
#      'lat': 14.566693198467448,
#      'lng': 121.06584988296503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566693198467448,
#        'lng': 121.06584988296503}],
#      'distance': 251,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pinagbuhatan', 'Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d113951735',
#       'name': 'Gas Station',
#       'pluralName': 'Gas Stations',
#       'shortName': 'Gas Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '53feecaf498ebc59b62fad22',
#     'name': 'Toasted Mallows Studio',
#     'location': {'address': '35b felipe pike',
#      'crossStreet': 'Street',
#      'lat': 14.567739021921456,
#      'lng': 121.0692868622975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567739021921456,
#        'lng': 121.0692868622975}],
#      'distance': 136,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['35b felipe pike (Street)',
#       'Pasig City District 1, Pasig, National Capital Region',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4eb1bdde3b7b55596b4a7490',
#       'name': 'Photography Lab',
#       'pluralName': 'Photography Labs',
#       'shortName': 'Photography Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/photographylab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4d1dd9ab16cfb60c16b84261',
#     'name': 'benj town',
#     'location': {'lat': 14.567858,
#      'lng': 121.067582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567858,
#        'lng': 121.067582}],
#      'distance': 83,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '53d937f3498eea0d8e5b1fda',
#     'name': 'mile hi diner tagaytay',
#     'location': {'lat': 14.567662003777038,
#      'lng': 121.06804418730272,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567662003777038,
#        'lng': 121.06804418730272}],
#      'distance': 40,
#      'cc': 'PH',
#      'city': 'Tagaytay',
#      'state': 'Cavite',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Tagaytay', 'Cavite', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
# ...
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4f75e449e4b0b24b0c3ca139',
#     'name': 'Rancho Elena',
#     'location': {'lat': 14.567525,
#      'lng': 121.066916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567525,
#        'lng': 121.066916}],
#      'distance': 130,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1e4941735',
#       'name': 'Campground',
#       'pluralName': 'Campgrounds',
#       'shortName': 'Campground',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '516f9185498ee19e16c82496',
#     'name': 'Reyes Haircutters Express',
#     'location': {'lat': 14.566773183254007,
#      'lng': 121.0676803385886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566773183254007,
#        'lng': 121.0676803385886}],
#      'distance': 74,
#      'cc': 'PH',
#      'city': 'Pasig-Mandaluyong',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig-Mandaluyong', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5179c53ce4b0a57be5adfbd5',
#     'name': 'At "My Sanctuar-E"',
#     'location': {'crossStreet': 'Lake view Drive',
#      'lat': 14.567639230157098,
#      'lng': 121.06700861499193,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567639230157098,
#        'lng': 121.06700861499193}],
#      'distance': 123,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Lake view Drive', 'Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5611d738498e7b6dea6e4b8c',
#     'name': 'URC - Human Resource Department',
#     'location': {'lat': 14.567931,
#      'lng': 121.069713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567931,
#        'lng': 121.069713}],
#      'distance': 187,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '515e5c30498ee74c8248cd88',
#     'name': 'URC - CIA',
#     'location': {'lat': 14.56815242767334,
#      'lng': 121.0698013305664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56815242767334,
#        'lng': 121.0698013305664}],
#      'distance': 206,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '50b5a765e4b0f3791b0d4e7f',
#     'name': 'Mipow HQ',
#     'location': {'lat': 14.56851430756068,
#      'lng': 121.06947718075662,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56851430756068,
#        'lng': 121.06947718075662}],
#      'distance': 200,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'shortName': 'Electronics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4f368931be770642eac27e1c',
#     'name': 'Asia Pacific Cosmetics Phils. Corp. (JML)',
#     'location': {'address': '41 Felipe Pike St. (formerly Kamagong St.) Bagong Ilog',
#      'lat': 14.567042448395203,
#      'lng': 121.06931447982788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567042448395203,
#        'lng': 121.06931447982788}],
#      'distance': 133,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['41 Felipe Pike St. (formerly Kamagong St.) Bagong Ilog',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d10c951735',
#       'name': 'Cosmetics Shop',
#       'pluralName': 'Cosmetics Shops',
#       'shortName': 'Cosmetics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4e0ada1b149563b079c1b0e2',
#     'name': 'IXM',
#     'location': {'address': '35 Lakeview Drive, Bagong Ilog',
#      'lat': 14.56757668923013,
#      'lng': 121.06676864127077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.56757668923013,
#        'lng': 121.06676864127077}],
#      'distance': 146,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['35 Lakeview Drive, Bagong Ilog',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4ec9b6e5b634b2fd7718dafb',
#     'name': 'Creativestuff Inc.',
#     'location': {'lat': 14.568338394165039,
#      'lng': 121.06676483154297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568338394165039,
#        'lng': 121.06676483154297}],
#      'distance': 184,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4dc901251f6e936efe4fcf7d',
#     'name': 'CSI Advertising',
#     'location': {'address': 'Lake View Drive',
#      'lat': 14.567712726065679,
#      'lng': 121.06752920110665,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567712726065679,
#        'lng': 121.06752920110665}],
#      'distance': 76,
#      'postalCode': '1605',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Lake View Drive',
#       '1605 Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4d6af0389d7e2d439ac71bb3',
#     'name': 'SJLM Enterprise HQ',
#     'location': {'address': '#22 Kabutihan St.',
#      'crossStreet': 'Kawilihan Village',
#      'lat': 14.567853,
#      'lng': 121.067551,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567853,
#        'lng': 121.067551}],
#      'distance': 85,
#      'postalCode': '1600',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['#22 Kabutihan St. (Kawilihan Village)',
#       '1600 Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '52045ef6498e2c98af6b5851',
#     'name': 'Little Ones',
#     'location': {'lat': 14.566450119018555,
#      'lng': 121.06664276123047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566450119018555,
#        'lng': 121.06664276123047}],
#      'distance': 183,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4eb1bdde3b7b55596b4a7490',
#       'name': 'Photography Lab',
#       'pluralName': 'Photography Labs',
#       'shortName': 'Photography Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/photographylab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4f790769e4b0e6832a59c376',
#     'name': 'Starlaser',
#     'location': {'lat': 14.566914,
#      'lng': 121.066199,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566914,
#        'lng': 121.066199}],
#      'distance': 209,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4e095020d22d658532b19c3d',
#     'name': 'NCCRI',
#     'location': {'lat': 14.568552,
#      'lng': 121.069343,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568552,
#        'lng': 121.069343}],
#      'distance': 193,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5035bb16e4b08ff192b7cdb8',
#     'name': "Dexter's Laboratory",
#     'location': {'crossStreet': 'Kawilihan Village',
#      'lat': 14.566795421483638,
#      'lng': 121.06934843594962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566795421483638,
#        'lng': 121.06934843594962}],
#      'distance': 145,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Kawilihan Village', 'Pasig', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '4ebcb0f78b81967ad19b1116',
#     'name': 'URC - HR department',
#     'location': {'address': '2F Brittania Building',
#      'lat': 14.568,
#      'lng': 121.069736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568,
#        'lng': 121.069736}],
#      'distance': 192,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['2F Brittania Building',
#       'Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '50d5abafe4b02f739476243b',
#     'name': 'Chikeninay',
#     'location': {'address': 'Pineda Pasig',
#      'lat': 14.568210222851084,
#      'lng': 121.0684864019492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568210222851084,
#        'lng': 121.0684864019492}],
#      'distance': 109,
#      'cc': 'PH',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pineda Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d120941735',
#       'name': 'Karaoke Bar',
#       'pluralName': 'Karaoke Bars',
#       'shortName': 'Karaoke',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5077adede4b018ca94d575ef',
#     'name': 'JML Direct',
#     'location': {'address': '41 Felipe Street',
#      'lat': 14.567112,
#      'lng': 121.069446,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.567112,
#        'lng': 121.069446}],
#      'distance': 146,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['41 Felipe Street',
#       'Pasig City',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4eb1bea83b7b6f98df247e06',
#       'name': 'Factory',
#       'pluralName': 'Factories',
#       'shortName': 'Factory',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/factory_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '5391f3bd498e932c3f00493d',
#     'name': 'JVACC HEAD OFFICE',
#     'location': {'address': 'JVACC HEAD OFFICE #1 E ROD. JR AVE BAGONG ILOG PASIG CITY',
#      'lat': 14.566075,
#      'lng': 121.069858,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.566075,
#        'lng': 121.069858}],
#      'distance': 233,
#      'postalCode': '1600',
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['JVACC HEAD OFFICE #1 E ROD. JR AVE BAGONG ILOG PASIG CITY',
#       '1600 Pasig',
#       'Pasig',
#       'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False},
#    {'id': '55c18d69498ecde9f250e72b',
#     'name': 'URC - Brittania Building',
#     'location': {'lat': 14.568219587975149,
#      'lng': 121.0698914022433,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 14.568219587975149,
#        'lng': 121.0698914022433}],
#      'distance': 218,
#      'cc': 'PH',
#      'city': 'Pasig',
#      'state': 'Pasig',
#      'country': 'Pilipinas',
#      'formattedAddress': ['Pasig City', 'Pasig', 'Pilipinas']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587471942',
#     'hasPerk': False}],
#   'confident': False}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
from pandas.io.json import json_normalize

venues = results['response']['venues'][0]
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-713f604d9dfc> in <module>
#       7 # filter columns
#       8 filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
# ----> 9 nearby_venues =nearby_venues.loc[:, filtered_columns]
#      10
#      11 # filter the category for each row
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
# -> 1839                 return self._getitem_iterable(key, axis=axis)
#    1840
#    1841             # nested tuple slicing
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1131         else:
#    1132             # A collection of keys
# -> 1133             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1134             return self.obj._reindex_with_indexers(
#    1135                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['venue.name', 'venue.categories', 'venue.location.lat',\n       'venue.location.lng'],\n      dtype='object')] are in the [columns]"
